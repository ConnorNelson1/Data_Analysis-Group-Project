# %% [markdown]
# CONNOR NELSON & FAITH CAMP & SANDRA KETA

# %% [markdown]
# The dataset that our group is working with is the arrest data of Chapel Hill, North Carolina from the years 2010 to 2016. Features include the date and time the arrest was made, as well as the address of the arrest. The crime committed is given to us as a classification of a felony or a misdemeanor, a UCR code, and a short description of the crime. The arrestee is described with features of age, race, sex, and ethnicity. The dataset has 18,809 rows and 11 features (columns).
#
# Our goal of analyzing this data set is to figure out if we can determine the age and gender of an arrestee given a crime. Doing this would allow us to see trends in crime among certain age groups, for example: all underage drinking crimes are committed by people under the age of 21. However, our analysis would like to look at less obvious tendencies in arrest data relating to other crimes. We would also like to observe gender’s role in the arrest data, and see if there are any trends in certain crimes only being committed by one gender or the other (or if there are no discrepancies at all). With this analysis, we can get a better picture of what crimes are associated with what demographic in Chapel Hill during this time period by looking at one feature at a time. This is a question of classification.
#
# We will be approaching this analysis while taking into account current and supported crime trend data regarding gender and race when it comes to the commission of crime. While analyzing the data, we are aware of the biases that police tend to have while carrying out arrests and law enforcement, and therefore recognize that this bias, has the potential to overrepresent the African American or Minority race in this data frame. We are also aware of the researched and supported trends regarding gender. Men are more likely to commit crime than women; men are more likely to commit violent crime, while women are more likely to commit property crime life larceny and other forms of theft. Taking this into account, it is our goal to use gender as a potential control variable to limit its impact and influence on the results, by skewing the data one way or the other.
#
# Next, we will look at changing our question to be a better example of classification by looking at age, gender, and race and using those features to predict their crime. We will also try to fix our problems with linear regression, since it shows we have 0 axes.

# %%
import numpy as np                   # Numerical computation library
import pandas as pa                  # Dataframe and Data manipulation Library
import matplotlib.pyplot as plt      # Basic plotting functionality Library
import seaborn as sn

# %%
pam = pa.read_csv('/Users/sandraketa/Desktop/police-arrests-made.csv', sep = ';')

# %% [markdown]
# The pairplot below only shows two features. This is because only these two are numeric values, whereas the rest are objects. As a result, this is not a good way to compare these variables.

# %%
sn.set(style = 'darkgrid')

p = sn.pairplot(pam)   

p.fig.set_size_inches(9, 9)

# %% [markdown]
# The histogram below shows the comparison between the black attribute for race and the six other race markers. The African American arrest numbers are JUST below that of the other six races combined. This speaks to the bias that police might have while conducting daily patrols. We are hoping to narrow down these biases and see if they are particular or correlated with specific crimes or crime groups.

# %%
sn.set(style = 'darkgrid') 
plt.figure(figsize = (10, 8))

sn.distplot(pam[pam.arrestee_s_race=='B'].arrestee_s_age, color='blue', 
            label='Minorities Arrests', kde=True, bins=14) 
sn.distplot(pam[pam.arrestee_s_race!='B'].arrestee_s_age, color='red', 
            label='Non_Minority Arrests', kde=True, bins=14)
plt.legend();

# %%
sn.set(style = 'darkgrid') 
plt.figure(figsize = (10, 8))

sn.distplot(pam[pam.arrestee_s_race=='B'].arrestee_s_age, color='blue', 
            label='African American Arrests', kde=True, bins=14) 

sn.distplot(pam[pam.arrestee_s_race!='B'].arrestee_s_age, color='red', 
            label='White & Hispanic Arrests', kde=True, bins=14)

sn.distplot(pam[pam.arrestee_ethnicity!='H'].arrestee_s_age, color='green', 
            label='Hispanic Arrests', kde=True, bins=14)

plt.legend();

# %% [markdown]
# These are the attributes for race. A for Asian, B for Black (African American), H for Hispanic, I for Indian (Native American), O for Other, U for Unknown, W for White, and nan for missing data.

# %%
set(pam.arrestee_s_race)
# Out:
# {'A', 'B', 'H', 'I', 'O', 'U', 'W', nan}

# %%
set(pam.arrestee_ethnicity)
# Out:
# {'H', nan}

# %% [markdown]
# This below is the initial form of our deeper analysis. We are going to grab the counts for each of the races with respect to the three crimes we have chosen. The three crimes, as of our initial pool selections are; IMPAIRED DRIVING - DWI, SECOND DEGREE TRESPASS, and ASSAULT - SIMPLE. We will look at the spread of the total number of these crimes committed across these racial groups, this will give us further info on the policing habits of Chapel Hill North Carolina. This initial attempt did not work, and it is our belief that it did not work initially, due to the presence of the 'nan' term in the variables for race. We are looking to remove that , and recode it as 'U' unknown, and run the test again and see if it works this time. Further research and analysis is to follow.

# %%
pamC = pa.read_csv('../police-arrests-made.csv', sep = ';')
pamC = pamC.loc[:, ['charge_description', 'arrestee_s_race']]  # Keep only the columns we want here
pamC.loc[:, 'COUNT'] = 1   # Add a variable for counting unique values
pamC = pamC.groupby(['charge_description', 'arrestee_s_race']).sum()   
 # Sum the values after grouping by County, 
       # City, and Provider Type
    
pamC.head()

#pamAn = pamC.reset_index().loc[:, ['charge_description', 'arrestee_s_race', 'COUNT']]  

## Drop the city and go back to a full data frame.

#pamAn = pamAn.groupby(['charge_description', 'arrestee_s_race']).sum()

## Redo the gather but now ignoring City

#pamAn = pamAn.reset_index()

## Set it back to a full data frame.

#pamAn = pamAn[pamAn['arrestee_s_race']=='Preschool Program']

#plt.figure(figsize = (10, 15))
#sn.set(style='darkgrid')
#sn.barplot(x='arrestee_s_race', y='COUNT', data=pamAn)
#plt.title('Crimes divided by Race Count');
# Out:
#                                                               COUNT
# charge_description                           arrestee_s_race
# (FTA) COMMUNICATE THREATS                    W                    1
# (FTA) HIT/RUN LEAVE SCENE OF PROPERTY DAMAGE B                    1
# (FTA) RECKLESS DRIVING                       B                    1
# (FTA) SPEEDING                               B                    1
# (OFA) PROBATION VIOLATION                    W                    1

# %%
pamC.tail()
# Out:
#                                                 COUNT
# charge_description             arrestee_s_race
# WORTHLESS CHECK                W                   19
# WORTHLESS CHECKS               B                    1
# WRONG WAY - ONE WAY ST         B                    1
#                                W                    1
# WRONG WAY ON DUAL LANE HIGHWAY W                    2

# %%
pamC.shape
# Out:
# (1834, 1)

# %%
pamAn = pamC.reset_index().loc[:, ['charge_description', 'arrestee_s_race', 'COUNT']]  

## Drop the city and go back to a full data frame.

pamAn = pamAn.groupby(['charge_description', 'arrestee_s_race']).sum()

## Redo the gather but now ignoring City

pamAn = pamAn.reset_index()

## Set it back to a full data frame.

pamAn = pamAn[pamAn['arrestee_s_race']=='B']

plt.figure(figsize = (15, 15))
#sn.set(style='darkgrid')
sn.barplot(x='arrestee_s_race', y='COUNT', data=pamAn)
#plt.title('Crimes divided by Race Count');

# %%
# Impared Driving DWI
# Second Degree Trespass
# Assault - Simple

# %%
sn.barplot(x = 'charge_description', y = 'COUNT', data = pamC.reset_index() )

# %%
pamC
# Out:
#                                                                    COUNT
# charge_description                                arrestee_s_race
# (FTA) COMMUNICATE THREATS                         W                    1
# (FTA) HIT/RUN LEAVE SCENE OF PROPERTY DAMAGE      B                    1
# (FTA) RECKLESS DRIVING                            B                    1
# (FTA) SPEEDING                                    B                    1
# (OFA) PROBATION VIOLATION                         W                    1
# (WFA) KILL ANIMAL BY STARVATION                   B                    1
# 13-2 SOLICIT W/O PERMIT                           B                    1
# 18B-300(C)                                        B                    1
# 1ST DEGREE TRESPASS                               A                    1
#                                                   B                   37
#                                                   O                    1
#                                                   W                   23
# 2ND DEG KIDNAPPING                                W                    1
# 2ND DEGREE KIDNAPPING                             W                    1
# 2ND DEGREE TRESPASS                               A                    9
#                                                   B                  268
#                                                   W                  154
# 2ND DEGREE TRESPASSING                            B                    1
# 2ND DEGREETRESPASS                                W                    1
# 50-B-3     PROTECTIVE ORDER                       W                    1
# 70MPH IN 45MPH ZONE                               W                    1
# ACCESSING COMPUTERS                               B                    1
# ACCESSORY-AFTER FACT                              B                    4
# ACCESSORY-AFTER FACT (ATTEMPT MURDER)             B                    1
# ADW-KNIFE                                         B                    1
# ADW-LAW ENF OFFICER                               W                    2
# ADW-OTHER WEAPON                                  B                    7
# AFFRAY                                            B                   13
#                                                   W                    4
# AFFRAY- NO PC FOUND                               W                    1
# ...                                                                  ...
# VIOLATION OF RELEASE ORDER- FTA FOR B/E (FEL)     W                    1
# VIOLATION OF RELEASE ORDER- FTA LARCENY AFTER B/E W                    1
# VIOLATIONS; ALTERATION AND REVOCATION PROBATION   B                    2
# WARRANT FOR ARREST                                A                    1
#                                                   B                  101
#                                                   H                    1
#                                                   I                    1
#                                                   W                   35
# WARRANT FOR ARREST 2ND DEGREE TRESPASS            W                    1
# WARRANT FOR ARREST COMMUNICATING THREATS          B                    1
# WARRANT FOR ARREST/B&E AND LARCENY                W                    1
# WARRANT FOR ARREST/SAFECRACKING                   W                    1
# WEAP - COURT / STATE PROPERTY                     B                    1
# WEAP-POSS BY FELON                                A                    1
#                                                   B                   38
#                                                   W                    4
# WEAP-POSS WITH ALCOHOL IN BODY                    W                    1
# WEAP-SCHOOL PROPERTY                              A                    1
#                                                   B                   10
#                                                   W                   13
# WEAPON ON SCHOOL PROPERTY                         W                    1
# WEARING MASKS,HOODS,ETC  ON STREETS               W                    1
# WFA - DWLR                                        B                    1
# WILD DANGEROUS ANIMAL VIOLATION                   I                    1
# WORTHLESS CHECK                                   B                   36
#                                                   W                   19
# WORTHLESS CHECKS                                  B                    1
# WRONG WAY - ONE WAY ST                            B                    1
#                                                   W                    1
# WRONG WAY ON DUAL LANE HIGHWAY                    W                    2
#
# [1834 rows x 1 columns]

# %%
set(pam.ucr_code)
# Out:
# {110.0,
#  640.0,
#  nan,
#  200.0,
#  300.0,
#  410.0,
#  411.0,
#  510.0,
#  620.0,
#  630.0,
#  670.0,
#  690.0,
#  710.0,
#  810.0,
#  811.0,
#  820.0,
#  900.0,
#  1015.0,
#  1027.0,
#  1110.0,
#  1120.0,
#  1140.0,
#  1150.0,
#  1170.0,
#  1180.0,
#  1190.0,
#  1210.0,
#  1290.0,
#  1310.0,
#  1320.0,
#  1330.0,
#  1400.0,
#  1530.0,
#  1550.0,
#  1590.0,
#  1710.0,
#  1720.0,
#  1730.0,
#  1770.0,
#  1780.0,
#  1810.0,
#  1820.0,
#  1834.0,
#  1890.0,
#  2020.0,
#  2030.0,
#  2090.0,
#  2100.0,
#  2212.0,
#  2214.0,
#  2222.0,
#  2223.0,
#  2230.0,
#  2240.0,
#  2290.0,
#  2410.0,
#  2430.0,
#  2440.0,
#  2450.0,
#  2490.0,
#  2520.0,
#  2570.0,
#  2590.0,
#  2620.0,
#  2630.0,
#  2640.0,
#  2650.0,
#  2660.0,
#  2670.0,
#  2680.0,
#  2690.0,
#  4010.0,
#  9910.0}

# %% [markdown]
# Violent Crime Codes:
#     0110 - Murder-First Degree-Attempt
#     0640 - B&E-Vehicle
#     0200 - Rape 1st Degree
#     0300 - Common Law Robbery
#     0410 - Assault Inflicting Serious Injury
#     0411 - Assault LEO & Inflicting Injury
#     0510 - B&E Misdemeanor
#     0810 - Assault & Battery
#     0811 - Assault on Government Official
#     0820 - Communicate Threats
#     1530 - Carrying Concealed Weapon Illegally
#     1550 - Discharging Firearm/ BB Gun
#     1590 - Possessing Weapon of Mass Destruction
#     1710 - Peeping
#     1720 - Crime against Nature
#     1730 - Indecent Exposure
#     1770 - Statutory Rape/Sex Offense
#     1780 - Child Indecent Liberties
#     2030 - Contributing to the Delinquency of a Minor
#     2090 - Assault on a Female
#     2100 - Impaired Driving DWI
#     2212 - Inderage Possession of Spiritious Liquor
#     2214 - Open Container
#     2222 - Underage Possession
#     2223 - Driver Consuming
#     2230 - Aid & Abet Underage Alcohol Usage
#     2240 - Consuming ON OFF Premises
#     2290 - Consuming on Unauthorized Premises
#     2410 - Disorderly Conduct
#     2430 - Fighting
#     2440 - Failure to Disperse
#     2450 - Drunk/Dispruptive
#     2490 - False Imprisonment
#     2520 - Dissemination of Obscene Material to a Minor (Under 16)
#     2570 - Exploiting Child
#     2590 - Performing Harmful or Obscene acts in front of a minor
#     2620 - Kidnapping
#     2630 - Resising Arrest
#     2640 - Violating Domestic Violence Protective Order
#     2650 - Obstructing LEO Work
#     2660 - Parole Violation
#     2670 - 2nd Degree Trespassing
#     2680 - Public Urination
#     2690 - Fugitive
#     4010 - Driving While License Revoked
#
#
# Property Crime Codes:
#     0620 - Larceny from person
#     0630 - Larceny (Switch Price Tag)
#     0670 - Break Coin Machine
#     0690 - Larceny All other
#     0710 - MV Theft - Automobile
#     0900 - Arson 1st Degree
#     1015 - Forgery-Uttering
#     1027 - Counterfeiting
#     1110 - Fraud - Worthless Check
#     1120 - Possession of Fraudulent ID
#     1140 - Unauthorized use of Conveyance
#     1150 - Credit Card Fraud
#     1170 - Identity Theft
#     1180 - Accessing Computers
#     1190 - Manufacturing Fraudulent Forms of ID
#     1210 - Embezzlement
#     1290 - Larceny by Employees
#     1310 - Recreational Stolen Goods
#     1320 - Larceny from Person
#     1330 - Possession of Stolen Goods
#     1400 - Damage-Personal Property
#     2020 - Non-Support Child
#     9910 - Littering
#
# Narcotic Crime Codes:
#     1810 - Poss Narcotics
#     1820 - Drugs-Counterfeit
#     1834 - Drug Paraphernalia
#     1890 - Drugs on School Property

# %%
pam = pa.read_csv('../police-arrests-made.csv', sep = ';')

pam_dict1 = {x:'Violent Crime' for x in list(set(pam.ucr_code))
             if x in [110,640,200,300,410,411,510,810,811,820,1530
                      ,1550,1590,1710,1720,1730,1770,1780,2030,2090,2100,2212,
                      2214,2222,2223,2230,2240,2290,2410,2430,2440,2450,2490,
                      2520,2570,2590,2620,2630,2640,2650,2670,2680,2690,4010]}
pam_dict2 = {x:'Property Crime' for x in list(set(pam.ucr_code)) 
             if x in[620,630,670,690,710,900,1015,1027,1110,1120,1140,1150,1170,1180,1190,1210,1290,1310,1320,
                      1330,1400,2020]}
pam_dict3 = {x:'Narcotic Crime' for x in list (set(pam.ucr_code))
             if x in [1810,1820,1834,1890]}

pam_dict1.update(pam_dict2) # merge the two dictionaries

pam_dict1.update(pam_dict3) # merge the third dictionary


pam_2 = pam.copy()   # pandas.dataframe is a mutable object so we use the .copy() command 
                         # otherwise changes to pam_2 will change major
    
pam_2.ucr_code = pam_2.ucr_code.map(pam_dict1)  # use the dictionary we made to recode the values with .map()

pam_2 # print the dataframe to check if there is a problem
# Out:
#       armainid arrest_date arrest_time  \
# 0       31,198  2013-11-11    10:58 PM
# 1       31,201  2013-11-12     2:38 PM
# 2       31,209  2013-11-15     3:50 PM
# 3       31,216  2013-11-20     4:44 AM
# 4       31,216  2013-11-20     4:44 AM
# 5       31,237  2013-11-24     1:05 AM
# 6       31,243  2013-11-24    10:57 AM
# 7       31,260  2013-11-28     9:21 PM
# 8       31,274  2013-12-06    12:00 PM
# 9       31,278  2013-12-08     3:47 AM
# 10      31,301  2013-12-14     6:37 PM
# 11      31,344  2013-12-28     5:47 PM
# 12      31,348  2013-12-30     1:24 AM
# 13      31,368  2014-01-07     4:34 AM
# 14      31,393  2014-01-12     2:00 AM
# 15      31,441  2014-01-23     8:04 PM
# 16      31,510  2014-02-15     2:38 AM
# 17      31,520  2014-02-18    11:48 AM
# 18      31,522  2014-02-18     7:53 PM
# 19      31,524  2014-02-19    10:26 PM
# 20      31,525  2014-02-20     1:02 AM
# 21      31,530  2014-02-02     6:10 PM
# 22      31,533  2014-02-21     4:45 AM
# 23      31,549  2014-02-23     2:52 AM
# 24      31,589  2014-03-04     9:07 PM
# 25      31,594  2014-03-08     4:47 AM
# 26      31,595  2014-03-08     5:04 PM
# 27      31,599  2014-03-10     8:25 PM
# 28      31,601  2014-03-11     1:46 AM
# 29      31,663  2014-03-26    12:39 AM
# ...        ...         ...         ...
# 18779   26,171  2011-01-30     1:05 AM
# 18780   26,181  2011-01-30     9:02 PM
# 18781   26,193  2011-02-02     3:00 PM
# 18782   26,199  2011-02-02     3:21 PM
# 18783   26,203  2011-02-04     2:19 AM
# 18784   31,122  2013-10-23     6:25 PM
# 18785   26,237  2011-02-10     4:03 PM
# 18786   31,137  2013-10-28    11:27 AM
# 18787   26,256  2011-02-14     7:46 PM
# 18788   26,270  2011-02-17     7:32 AM
# 18789   26,274  2011-02-17     4:03 PM
# 18790   24,143  2010-01-17     1:37 AM
# 18791   26,280  2011-02-18     1:30 AM
# 18792   24,145  2010-01-17     2:06 AM
# 18793   26,309  2011-02-23     2:04 AM
# 18794   24,170  2010-01-24     8:32 AM
# 18795   24,180  2010-01-28     4:40 PM
# 18796   24,184  2010-01-29     3:30 PM
# 18797   26,379  2011-03-06    12:12 AM
# 18798   24,196  2010-02-03     8:37 PM
# 18799   26,387  2011-03-08    11:30 AM
# 18800   24,221  2010-02-08     5:18 AM
# 18801   26,419  2011-03-16     1:16 AM
# 18802   24,304  2010-02-22     6:57 PM
# 18803   26,438  2011-03-18     1:30 AM
# 18804   26,456  2011-03-18     7:31 PM
# 18805   24,370  2010-03-12     4:10 PM
# 18806   26,497  2011-03-26    11:53 PM
# 18807   24,402  2010-03-18     9:16 PM
# 18808   26,509  2011-03-29     9:03 PM
#
#                                                  address  \
# 0                100 N COLUMBIA ST CHAPEL HILL, NC 27514
# 1      828 MARTIN LUTHER KING JR BLVD CHAPEL HILL, NC...
# 2                100 W ROSEMARY ST CHAPEL HILL, NC 27516
# 3             MLK/NEW STATESIDE DR CHAPEL HILL, NC 27514
# 4             MLK/NEW STATESIDE DR CHAPEL HILL, NC 27514
# 5                112 W FRANKLIN ST CHAPEL HILL, NC 27514
# 6               1105 HWY 54 BYPASS CHAPEL HILL, NC 27514
# 7             2525 BOOKER CREEK RD CHAPEL HILL, NC 27514
# 8                   201 S ESTES DR CHAPEL HILL, NC 27514
# 9                     120 BANKS DR CHAPEL HILL, NC 27514
# 10                113 PINEGATE CIR CHAPEL HILL, NC 27514
# 11               409 W FRANKLIN ST CHAPEL HILL, NC 27516
# 12         NC 54 E/W BARBEE CHAPEL CHAPEL HILL, NC 27514
# 13            209 ASHLEY FOREST RD CHAPEL HILL, NC 27514
# 14           112 1/2 W FRANKLIN ST CHAPEL HILL, NC 27514
# 15                  751 TRINITY CT CHAPEL HILL, NC 27516
# 16               127 E FRANKLIN ST CHAPEL HILL, NC 27514
# 17             500 WEAVER DAIRY RD CHAPEL HILL, NC 27514
# 18               216 N ROBERSON ST CHAPEL HILL, NC 27516
# 19             525 HILLSBOROUGH ST CHAPEL HILL, NC 27514
# 20              1516 E FRANKLIN ST CHAPEL HILL, NC 27514
# 21              127 EAST FRANKLIN STREET CHAPEL HILL, NC
# 22                      KENMORE RD CHAPEL HILL, NC 27514
# 23       WEST CAMERON/KENAN STREET CHAPEL HILL, NC 27514
# 24              1301 E FRANKLIN ST CHAPEL HILL, NC 27514
# 25               140 W FRANKLIN ST CHAPEL HILL, NC 27516
# 26                        STARLITE DR CARRBORO, NC 27510
# 27                 510 COOLIDGE ST CHAPEL HILL, NC 27516
# 28               1301 FORDHAM BLVD CHAPEL HILL, NC 27517
# 29                   500 CHURCH ST CHAPEL HILL, NC 27516
# ...                                                  ...
# 18779               157 EAST ROSEMARY ST CHAPEL HILL, NC
# 18780    HWY 15-501 S @ BENNETT RD CHAPEL HILL, NC 27514
# 18781             220 ELIZABETH ST CHAPEL HILL, NC 27514
# 18782        750 S MERRITT MILL RD CHAPEL HILL, NC 27516
# 18783     121 EAST FRANKLIN STREET CHAPEL HILL, NC 27514
# 18784  828 MARTIN LUTHER KING JR BLVD CHAPEL HILL, NC...
# 18785          TOWN PARKING LOT #2 CHAPEL HILL, NC 27514
# 18786          500 WEAVER DAIRY RD CHAPEL HILL, NC 27514
# 18787                 750 MLK BLVD CHAPEL HILL, NC 27514
# 18788  COLUMBIA ST AND FRANKLIN ST CHAPEL HILL, NC 27514
# 18789  828 MARTIN LUTHER KING JR BLVD CHAPEL HILL, NC...
# 18790     700 PRITCHARD AVENUE EXT CHAPEL HILL, NC 27514
# 18791      100 BLOCK E FRANKLIN ST CHAPEL HILL, NC 27516
# 18792                   S ESTES DR CHAPEL HILL, NC 27516
# 18793           1516 E FRANKLIN ST CHAPEL HILL, NC 27514
# 18794  828 MARTIN LUTHER KING JR BLVD CHAPEL HILL, NC...
# 18795     325 WEST ROSEMARY STREET CHAPEL HILL, NC 27514
# 18796  828 MARTIN LUTHER KING JR BLVD CHAPEL HILL, NC...
# 18797            506 W FRANKLIN ST CHAPEL HILL, NC 27516
# 18798                   309 E MAIN ST CARRBORO, NC 27510
# 18799  980 MARTIN LUTHER KING JR BLVD CHAPEL HILL, NC...
# 18800      ROSEMARY ST @ CHURCH ST CHAPEL HILL, NC 27514
# 18801            114 S COLUMBIA ST CHAPEL HILL, NC 27514
# 18802         104 NEW STATESIDE DR CHAPEL HILL, NC 27516
# 18803  EAST ROSEMARY AND NORTH COLUMBIA CHAPEL HILL, ...
# 18804            121 E FRANKLIN ST CHAPEL HILL, NC 27514
# 18805              106 N GRAHAM ST CHAPEL HILL, NC 27516
# 18806                25 BRANDON RD CHAPEL HILL, NC 27517
# 18807        1100 NC HWY 54 BYPASS CHAPEL HILL, NC 27516
# 18808         1129 WEAVER DAIRY RD CHAPEL HILL, NC 27514
#
#                                  charge_description        ucr_code  \
# 0                                    DRUGS-MAINTAIN  Narcotic Crime
# 1                                    ASSAULT-SIMPLE   Violent Crime
# 2                                 ASSAULT & BATTERY   Violent Crime
# 3                              IMPAIRED DRIVING DWI   Violent Crime
# 4                             DRIVING W/LIC REVOKED   Violent Crime
# 5                               UNDERAGE POSSESSION   Violent Crime
# 6                                 ASSAULT ON FEMALE   Violent Crime
# 7                              POSSESSION MARIJUANA  Narcotic Crime
# 8                       CONCEALING MDSE/SHOPLIFTING  Property Crime
# 9                                          FUGITIVE   Violent Crime
# 10                   ASSAULT ON GOVERNMENT OFFICIAL   Violent Crime
# 11                              2ND DEGREE TRESPASS   Violent Crime
# 12                            DRIVING W/LIC REVOKED   Violent Crime
# 13                                ASSAULT ON FEMALE   Violent Crime
# 14                              UNDERAGE POSSESSION   Violent Crime
# 15                             BREAKING/LARC-FELONY   Violent Crime
# 16                              2ND DEGREE TRESPASS   Violent Crime
# 17                             WEAP-SCHOOL PROPERTY   Violent Crime
# 18                                              CCW   Violent Crime
# 19                                   IDENTITY THEFT  Property Crime
# 20                          POSSESS METHAMPHETAMINE  Narcotic Crime
# 21                             DAMAGE-PERSONAL PROP  Property Crime
# 22                             IMPAIRED DRIVING DWI   Violent Crime
# 23                                        LITTERING   Violent Crime
# 24                          ASSAULT W DEADLY WEAPON   Violent Crime
# 25                            OPEN CONTAINER IN PVA   Violent Crime
# 26                              POSS STOLEN FIREARM  Property Crime
# 27     VIOLATION DOMESTIC VIOLENCE PROTECTIVE ORDER   Violent Crime
# 28                                   ASSAULT-SIMPLE   Violent Crime
# 29                          BATTERY OF UNBORN CHILD   Violent Crime
# ...                                             ...             ...
# 18779                              RESISTING ARREST   Violent Crime
# 18780                          DAMAGE-PERSONAL PROP  Property Crime
# 18781                              MAINTAIN VEHICLE  Narcotic Crime
# 18782                          POSSESSION MARIJUANA  Narcotic Crime
# 18783                              PUBLIC URINATION   Violent Crime
# 18784                          FAIL TO APPEAR/COMPL   Violent Crime
# 18785                           2ND DEGREE TRESPASS   Violent Crime
# 18786                          POSSESSION MARIJUANA  Narcotic Crime
# 18787                          POSS OF STOLEN GOODS  Property Crime
# 18788                                HIT & RUN - PD   Violent Crime
# 18789                              RESISTING ARREST   Violent Crime
# 18790                             REC/POSS STOLE MV  Property Crime
# 18791                              RESISTING ARREST   Violent Crime
# 18792                          FAIL TO APPEAR/COMPL   Violent Crime
# 18793                          IMPAIRED DRIVING DWI   Violent Crime
# 18794                              RESISTING ARREST   Violent Crime
# 18795                          POSSESSION MARIJUANA  Narcotic Crime
# 18796                          FAIL TO APPEAR/COMPL   Violent Crime
# 18797                              FAIL TO DISPERSE   Violent Crime
# 18798                              POSS COCAINE FEL  Narcotic Crime
# 18799                            DRUG PARAPHERNALIA  Narcotic Crime
# 18800                                      SPEEDING   Violent Crime
# 18801                            DRUNK / DISRUPTIVE   Violent Crime
# 18802                              RECKLESS DRIVING   Violent Crime
# 18803                           LIQUOR  - CONSUMING   Violent Crime
# 18804                            DRUNK / DISRUPTIVE   Violent Crime
# 18805                          FAIL TO APPEAR/COMPL   Violent Crime
# 18806                     NDL - SUSPENDED / REVOKED   Violent Crime
# 18807                             ASSAULT ON FEMALE   Violent Crime
# 18808                              RESISTING ARREST   Violent Crime
#
#       felony_or_misdemeanor  arrestee_s_age arrestee_s_race arrestee_s_sex  \
# 0                         M            32.0               B              M
# 1                         M            25.0               B              F
# 2                         M            27.0               W              M
# 3                         M            24.0               B              M
# 4                         M            24.0               B              M
# 5                         M            18.0               W              F
# 6                         M            34.0               B              M
# 7                         M            24.0               W              M
# 8                         M            54.0               W              F
# 9                         F            21.0               W              F
# 10                        M            22.0               W              M
# 11                        M            20.0               B              F
# 12                        M            30.0               B              M
# 13                        M            27.0               W              M
# 14                        M            20.0               W              M
# 15                        F            26.0               B              M
# 16                        M            29.0               B              M
# 17                        M            17.0               B              M
# 18                        M            30.0               B              M
# 19                        F            57.0               W              M
# 20                        F            26.0               B              M
# 21                        M            61.0               B              M
# 22                        M            29.0               W              M
# 23                        M            19.0               W              M
# 24                        M            55.0               A              M
# 25                        M            34.0               W              M
# 26                        F            21.0               B              M
# 27                        M            53.0               W              M
# 28                        M            35.0               W              M
# 29                        F            23.0               B              M
# ...                     ...             ...             ...            ...
# 18779                     M            19.0               W              F
# 18780                     M            38.0               B              M
# 18781                     F            32.0               B              M
# 18782                     M            17.0               B              F
# 18783                     M            29.0               W              M
# 18784                     M            56.0               B              M
# 18785                     M            75.0               W              M
# 18786                     M            19.0               W              M
# 18787                     M            53.0               B              M
# 18788                     M            24.0               W              F
# 18789                     M             NaN               W              M
# 18790                     F            25.0               B              M
# 18791                     M            26.0               B              M
# 18792                     M            33.0               B              M
# 18793                     M            31.0               B              M
# 18794                     M            22.0               W              F
# 18795                     M            26.0               B              M
# 18796                     M            24.0               W              M
# 18797                     M            22.0               B              F
# 18798                     F            51.0               B              M
# 18799                     M            26.0               W              F
# 18800                     M            32.0               B              M
# 18801                     M            43.0               W              F
# 18802                     M            32.0               W              M
# 18803                     M            21.0               W              M
# 18804                     M            50.0               B              M
# 18805                     M            41.0               B              M
# 18806                     M            27.0               W              M
# 18807                     M            45.0               W              M
# 18808                     M            51.0               W              M
#
#       arrestee_ethnicity
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# ...                  ...
# 18779                NaN
# 18780                NaN
# 18781                NaN
# 18782                NaN
# 18783                NaN
# 18784                NaN
# 18785                NaN
# 18786                NaN
# 18787                NaN
# 18788                NaN
# 18789                  H
# 18790                NaN
# 18791                NaN
# 18792                NaN
# 18793                NaN
# 18794                NaN
# 18795                NaN
# 18796                NaN
# 18797                NaN
# 18798                NaN
# 18799                NaN
# 18800                NaN
# 18801                NaN
# 18802                NaN
# 18803                NaN
# 18804                NaN
# 18805                NaN
# 18806                  H
# 18807                  H
# 18808                NaN
#
# [18809 rows x 11 columns]

# %%
pam.shape
# Out:
# (18809, 11)

# %%
pam.tail()
# Out:
#       armainid arrest_date arrest_time  \
# 18804   26,456  2011-03-18     7:31 PM
# 18805   24,370  2010-03-12     4:10 PM
# 18806   26,497  2011-03-26    11:53 PM
# 18807   24,402  2010-03-18     9:16 PM
# 18808   26,509  2011-03-29     9:03 PM
#
#                                            address         charge_description  \
# 18804      121 E FRANKLIN ST CHAPEL HILL, NC 27514         DRUNK / DISRUPTIVE
# 18805        106 N GRAHAM ST CHAPEL HILL, NC 27516       FAIL TO APPEAR/COMPL
# 18806          25 BRANDON RD CHAPEL HILL, NC 27517  NDL - SUSPENDED / REVOKED
# 18807  1100 NC HWY 54 BYPASS CHAPEL HILL, NC 27516          ASSAULT ON FEMALE
# 18808   1129 WEAVER DAIRY RD CHAPEL HILL, NC 27514           RESISTING ARREST
#
#        ucr_code felony_or_misdemeanor  arrestee_s_age arrestee_s_race  \
# 18804    2450.0                     M            50.0               B
# 18805    2640.0                     M            41.0               B
# 18806    4010.0                     M            27.0               W
# 18807     810.0                     M            45.0               W
# 18808    2650.0                     M            51.0               W
#
#       arrestee_s_sex arrestee_ethnicity
# 18804              M                NaN
# 18805              M                NaN
# 18806              M                  H
# 18807              M                  H
# 18808              M                NaN

# %%
set(pam_2.ucr_code)
# Out:
# {'Narcotic Crime', 'Property Crime', 'Violent Crime', nan}

# %%
pam = pa.read_csv('../police-arrests-made.csv', sep = ';')

pam_2_dict4 = {x: 0 for x in list(set(pam_2.ucr_code))
             if x in ['Violent Crime']}
pam_2_dict5 = {x: 1 for x in list(set(pam_2.ucr_code)) 
             if x in['Property Crime']}
pam_2_dict6 = {x: 2 for x in list (set(pam_2.ucr_code))
             if x in ['Narcotic Crime']}

pam_2_dict4.update(pam_2_dict5) # merge the two dictionaries

pam_2_dict4.update(pam_2_dict6) # merge the third dictionary


pam_3 = pam_2.copy()   # pandas.dataframe is a mutable object so we use the .copy() command 
                         # otherwise changes to pam_2 will change major
    
pam_3.ucr_code = pam_3.ucr_code.map(pam_2_dict4)  # use the dictionary we made to recode the values with .map()

pam_3 # print the dataframe to check if there is a problem
# Out:
#       armainid arrest_date arrest_time  \
# 0       31,198  2013-11-11    10:58 PM
# 1       31,201  2013-11-12     2:38 PM
# 2       31,209  2013-11-15     3:50 PM
# 3       31,216  2013-11-20     4:44 AM
# 4       31,216  2013-11-20     4:44 AM
# 5       31,237  2013-11-24     1:05 AM
# 6       31,243  2013-11-24    10:57 AM
# 7       31,260  2013-11-28     9:21 PM
# 8       31,274  2013-12-06    12:00 PM
# 9       31,278  2013-12-08     3:47 AM
# 10      31,301  2013-12-14     6:37 PM
# 11      31,344  2013-12-28     5:47 PM
# 12      31,348  2013-12-30     1:24 AM
# 13      31,368  2014-01-07     4:34 AM
# 14      31,393  2014-01-12     2:00 AM
# 15      31,441  2014-01-23     8:04 PM
# 16      31,510  2014-02-15     2:38 AM
# 17      31,520  2014-02-18    11:48 AM
# 18      31,522  2014-02-18     7:53 PM
# 19      31,524  2014-02-19    10:26 PM
# 20      31,525  2014-02-20     1:02 AM
# 21      31,530  2014-02-02     6:10 PM
# 22      31,533  2014-02-21     4:45 AM
# 23      31,549  2014-02-23     2:52 AM
# 24      31,589  2014-03-04     9:07 PM
# 25      31,594  2014-03-08     4:47 AM
# 26      31,595  2014-03-08     5:04 PM
# 27      31,599  2014-03-10     8:25 PM
# 28      31,601  2014-03-11     1:46 AM
# 29      31,663  2014-03-26    12:39 AM
# ...        ...         ...         ...
# 18779   26,171  2011-01-30     1:05 AM
# 18780   26,181  2011-01-30     9:02 PM
# 18781   26,193  2011-02-02     3:00 PM
# 18782   26,199  2011-02-02     3:21 PM
# 18783   26,203  2011-02-04     2:19 AM
# 18784   31,122  2013-10-23     6:25 PM
# 18785   26,237  2011-02-10     4:03 PM
# 18786   31,137  2013-10-28    11:27 AM
# 18787   26,256  2011-02-14     7:46 PM
# 18788   26,270  2011-02-17     7:32 AM
# 18789   26,274  2011-02-17     4:03 PM
# 18790   24,143  2010-01-17     1:37 AM
# 18791   26,280  2011-02-18     1:30 AM
# 18792   24,145  2010-01-17     2:06 AM
# 18793   26,309  2011-02-23     2:04 AM
# 18794   24,170  2010-01-24     8:32 AM
# 18795   24,180  2010-01-28     4:40 PM
# 18796   24,184  2010-01-29     3:30 PM
# 18797   26,379  2011-03-06    12:12 AM
# 18798   24,196  2010-02-03     8:37 PM
# 18799   26,387  2011-03-08    11:30 AM
# 18800   24,221  2010-02-08     5:18 AM
# 18801   26,419  2011-03-16     1:16 AM
# 18802   24,304  2010-02-22     6:57 PM
# 18803   26,438  2011-03-18     1:30 AM
# 18804   26,456  2011-03-18     7:31 PM
# 18805   24,370  2010-03-12     4:10 PM
# 18806   26,497  2011-03-26    11:53 PM
# 18807   24,402  2010-03-18     9:16 PM
# 18808   26,509  2011-03-29     9:03 PM
#
#                                                  address  \
# 0                100 N COLUMBIA ST CHAPEL HILL, NC 27514
# 1      828 MARTIN LUTHER KING JR BLVD CHAPEL HILL, NC...
# 2                100 W ROSEMARY ST CHAPEL HILL, NC 27516
# 3             MLK/NEW STATESIDE DR CHAPEL HILL, NC 27514
# 4             MLK/NEW STATESIDE DR CHAPEL HILL, NC 27514
# 5                112 W FRANKLIN ST CHAPEL HILL, NC 27514
# 6               1105 HWY 54 BYPASS CHAPEL HILL, NC 27514
# 7             2525 BOOKER CREEK RD CHAPEL HILL, NC 27514
# 8                   201 S ESTES DR CHAPEL HILL, NC 27514
# 9                     120 BANKS DR CHAPEL HILL, NC 27514
# 10                113 PINEGATE CIR CHAPEL HILL, NC 27514
# 11               409 W FRANKLIN ST CHAPEL HILL, NC 27516
# 12         NC 54 E/W BARBEE CHAPEL CHAPEL HILL, NC 27514
# 13            209 ASHLEY FOREST RD CHAPEL HILL, NC 27514
# 14           112 1/2 W FRANKLIN ST CHAPEL HILL, NC 27514
# 15                  751 TRINITY CT CHAPEL HILL, NC 27516
# 16               127 E FRANKLIN ST CHAPEL HILL, NC 27514
# 17             500 WEAVER DAIRY RD CHAPEL HILL, NC 27514
# 18               216 N ROBERSON ST CHAPEL HILL, NC 27516
# 19             525 HILLSBOROUGH ST CHAPEL HILL, NC 27514
# 20              1516 E FRANKLIN ST CHAPEL HILL, NC 27514
# 21              127 EAST FRANKLIN STREET CHAPEL HILL, NC
# 22                      KENMORE RD CHAPEL HILL, NC 27514
# 23       WEST CAMERON/KENAN STREET CHAPEL HILL, NC 27514
# 24              1301 E FRANKLIN ST CHAPEL HILL, NC 27514
# 25               140 W FRANKLIN ST CHAPEL HILL, NC 27516
# 26                        STARLITE DR CARRBORO, NC 27510
# 27                 510 COOLIDGE ST CHAPEL HILL, NC 27516
# 28               1301 FORDHAM BLVD CHAPEL HILL, NC 27517
# 29                   500 CHURCH ST CHAPEL HILL, NC 27516
# ...                                                  ...
# 18779               157 EAST ROSEMARY ST CHAPEL HILL, NC
# 18780    HWY 15-501 S @ BENNETT RD CHAPEL HILL, NC 27514
# 18781             220 ELIZABETH ST CHAPEL HILL, NC 27514
# 18782        750 S MERRITT MILL RD CHAPEL HILL, NC 27516
# 18783     121 EAST FRANKLIN STREET CHAPEL HILL, NC 27514
# 18784  828 MARTIN LUTHER KING JR BLVD CHAPEL HILL, NC...
# 18785          TOWN PARKING LOT #2 CHAPEL HILL, NC 27514
# 18786          500 WEAVER DAIRY RD CHAPEL HILL, NC 27514
# 18787                 750 MLK BLVD CHAPEL HILL, NC 27514
# 18788  COLUMBIA ST AND FRANKLIN ST CHAPEL HILL, NC 27514
# 18789  828 MARTIN LUTHER KING JR BLVD CHAPEL HILL, NC...
# 18790     700 PRITCHARD AVENUE EXT CHAPEL HILL, NC 27514
# 18791      100 BLOCK E FRANKLIN ST CHAPEL HILL, NC 27516
# 18792                   S ESTES DR CHAPEL HILL, NC 27516
# 18793           1516 E FRANKLIN ST CHAPEL HILL, NC 27514
# 18794  828 MARTIN LUTHER KING JR BLVD CHAPEL HILL, NC...
# 18795     325 WEST ROSEMARY STREET CHAPEL HILL, NC 27514
# 18796  828 MARTIN LUTHER KING JR BLVD CHAPEL HILL, NC...
# 18797            506 W FRANKLIN ST CHAPEL HILL, NC 27516
# 18798                   309 E MAIN ST CARRBORO, NC 27510
# 18799  980 MARTIN LUTHER KING JR BLVD CHAPEL HILL, NC...
# 18800      ROSEMARY ST @ CHURCH ST CHAPEL HILL, NC 27514
# 18801            114 S COLUMBIA ST CHAPEL HILL, NC 27514
# 18802         104 NEW STATESIDE DR CHAPEL HILL, NC 27516
# 18803  EAST ROSEMARY AND NORTH COLUMBIA CHAPEL HILL, ...
# 18804            121 E FRANKLIN ST CHAPEL HILL, NC 27514
# 18805              106 N GRAHAM ST CHAPEL HILL, NC 27516
# 18806                25 BRANDON RD CHAPEL HILL, NC 27517
# 18807        1100 NC HWY 54 BYPASS CHAPEL HILL, NC 27516
# 18808         1129 WEAVER DAIRY RD CHAPEL HILL, NC 27514
#
#                                  charge_description  ucr_code  \
# 0                                    DRUGS-MAINTAIN       2.0
# 1                                    ASSAULT-SIMPLE       0.0
# 2                                 ASSAULT & BATTERY       0.0
# 3                              IMPAIRED DRIVING DWI       0.0
# 4                             DRIVING W/LIC REVOKED       0.0
# 5                               UNDERAGE POSSESSION       0.0
# 6                                 ASSAULT ON FEMALE       0.0
# 7                              POSSESSION MARIJUANA       2.0
# 8                       CONCEALING MDSE/SHOPLIFTING       1.0
# 9                                          FUGITIVE       0.0
# 10                   ASSAULT ON GOVERNMENT OFFICIAL       0.0
# 11                              2ND DEGREE TRESPASS       0.0
# 12                            DRIVING W/LIC REVOKED       0.0
# 13                                ASSAULT ON FEMALE       0.0
# 14                              UNDERAGE POSSESSION       0.0
# 15                             BREAKING/LARC-FELONY       0.0
# 16                              2ND DEGREE TRESPASS       0.0
# 17                             WEAP-SCHOOL PROPERTY       0.0
# 18                                              CCW       0.0
# 19                                   IDENTITY THEFT       1.0
# 20                          POSSESS METHAMPHETAMINE       2.0
# 21                             DAMAGE-PERSONAL PROP       1.0
# 22                             IMPAIRED DRIVING DWI       0.0
# 23                                        LITTERING       0.0
# 24                          ASSAULT W DEADLY WEAPON       0.0
# 25                            OPEN CONTAINER IN PVA       0.0
# 26                              POSS STOLEN FIREARM       1.0
# 27     VIOLATION DOMESTIC VIOLENCE PROTECTIVE ORDER       0.0
# 28                                   ASSAULT-SIMPLE       0.0
# 29                          BATTERY OF UNBORN CHILD       0.0
# ...                                             ...       ...
# 18779                              RESISTING ARREST       0.0
# 18780                          DAMAGE-PERSONAL PROP       1.0
# 18781                              MAINTAIN VEHICLE       2.0
# 18782                          POSSESSION MARIJUANA       2.0
# 18783                              PUBLIC URINATION       0.0
# 18784                          FAIL TO APPEAR/COMPL       0.0
# 18785                           2ND DEGREE TRESPASS       0.0
# 18786                          POSSESSION MARIJUANA       2.0
# 18787                          POSS OF STOLEN GOODS       1.0
# 18788                                HIT & RUN - PD       0.0
# 18789                              RESISTING ARREST       0.0
# 18790                             REC/POSS STOLE MV       1.0
# 18791                              RESISTING ARREST       0.0
# 18792                          FAIL TO APPEAR/COMPL       0.0
# 18793                          IMPAIRED DRIVING DWI       0.0
# 18794                              RESISTING ARREST       0.0
# 18795                          POSSESSION MARIJUANA       2.0
# 18796                          FAIL TO APPEAR/COMPL       0.0
# 18797                              FAIL TO DISPERSE       0.0
# 18798                              POSS COCAINE FEL       2.0
# 18799                            DRUG PARAPHERNALIA       2.0
# 18800                                      SPEEDING       0.0
# 18801                            DRUNK / DISRUPTIVE       0.0
# 18802                              RECKLESS DRIVING       0.0
# 18803                           LIQUOR  - CONSUMING       0.0
# 18804                            DRUNK / DISRUPTIVE       0.0
# 18805                          FAIL TO APPEAR/COMPL       0.0
# 18806                     NDL - SUSPENDED / REVOKED       0.0
# 18807                             ASSAULT ON FEMALE       0.0
# 18808                              RESISTING ARREST       0.0
#
#       felony_or_misdemeanor  arrestee_s_age arrestee_s_race arrestee_s_sex  \
# 0                         M            32.0               B              M
# 1                         M            25.0               B              F
# 2                         M            27.0               W              M
# 3                         M            24.0               B              M
# 4                         M            24.0               B              M
# 5                         M            18.0               W              F
# 6                         M            34.0               B              M
# 7                         M            24.0               W              M
# 8                         M            54.0               W              F
# 9                         F            21.0               W              F
# 10                        M            22.0               W              M
# 11                        M            20.0               B              F
# 12                        M            30.0               B              M
# 13                        M            27.0               W              M
# 14                        M            20.0               W              M
# 15                        F            26.0               B              M
# 16                        M            29.0               B              M
# 17                        M            17.0               B              M
# 18                        M            30.0               B              M
# 19                        F            57.0               W              M
# 20                        F            26.0               B              M
# 21                        M            61.0               B              M
# 22                        M            29.0               W              M
# 23                        M            19.0               W              M
# 24                        M            55.0               A              M
# 25                        M            34.0               W              M
# 26                        F            21.0               B              M
# 27                        M            53.0               W              M
# 28                        M            35.0               W              M
# 29                        F            23.0               B              M
# ...                     ...             ...             ...            ...
# 18779                     M            19.0               W              F
# 18780                     M            38.0               B              M
# 18781                     F            32.0               B              M
# 18782                     M            17.0               B              F
# 18783                     M            29.0               W              M
# 18784                     M            56.0               B              M
# 18785                     M            75.0               W              M
# 18786                     M            19.0               W              M
# 18787                     M            53.0               B              M
# 18788                     M            24.0               W              F
# 18789                     M             NaN               W              M
# 18790                     F            25.0               B              M
# 18791                     M            26.0               B              M
# 18792                     M            33.0               B              M
# 18793                     M            31.0               B              M
# 18794                     M            22.0               W              F
# 18795                     M            26.0               B              M
# 18796                     M            24.0               W              M
# 18797                     M            22.0               B              F
# 18798                     F            51.0               B              M
# 18799                     M            26.0               W              F
# 18800                     M            32.0               B              M
# 18801                     M            43.0               W              F
# 18802                     M            32.0               W              M
# 18803                     M            21.0               W              M
# 18804                     M            50.0               B              M
# 18805                     M            41.0               B              M
# 18806                     M            27.0               W              M
# 18807                     M            45.0               W              M
# 18808                     M            51.0               W              M
#
#       arrestee_ethnicity
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# ...                  ...
# 18779                NaN
# 18780                NaN
# 18781                NaN
# 18782                NaN
# 18783                NaN
# 18784                NaN
# 18785                NaN
# 18786                NaN
# 18787                NaN
# 18788                NaN
# 18789                  H
# 18790                NaN
# 18791                NaN
# 18792                NaN
# 18793                NaN
# 18794                NaN
# 18795                NaN
# 18796                NaN
# 18797                NaN
# 18798                NaN
# 18799                NaN
# 18800                NaN
# 18801                NaN
# 18802                NaN
# 18803                NaN
# 18804                NaN
# 18805                NaN
# 18806                  H
# 18807                  H
# 18808                NaN
#
# [18809 rows x 11 columns]

# %%
set(pam.arrestee_s_race)
# Out:
# {'A', 'B', 'H', 'I', 'O', 'U', 'W', nan}

# %%
def onehot(df, feature):
    '''A function to do one-hot-encoding of a feature from a dataframe. df = dataframe'''

    pamv = list(set(df[feature])) # Make an iterable of the unique values for the feature
    
    for c in df.index: # cycle through the samples
        t = df.loc[c, feature]
        
        for test in pamv:
            if pa.isna(test):  # nan values are sort of a problem and have to be handled separately
                if pa.isna(t):
                    df.loc[c, '{}_nan'.format(feature)] = 1
                else:
                    df.loc[c, '{}_nan'.format(feature)] = 0
            else:
                if t == test:
                    df.loc[c, '{}_{}'.format(feature, test)] = 1  # Makes a new feature with name feature_value
                                                              # and codes it as a 1 if that was the value
                else:
                    df.loc[c, '{}_{}'.format(feature, test)] = 0  # and 0 otherwise
            
    return df.drop(feature, axis=1) # returns a dataframe with the encoded feature removed

# %%
pam_hot1 = onehot(pam_3, 'arrestee_s_race')
pam_hot1[30:40]
# Out:
#    armainid arrest_date arrest_time  \
# 30   31,697  2014-04-01     8:19 AM
# 31   31,719  2014-04-05     2:15 AM
# 32   31,730  2014-04-05     2:25 AM
# 33   31,761  2014-04-10    12:20 PM
# 34   31,763  2014-04-10     4:30 PM
# 35   31,763  2014-04-10     4:30 PM
# 36   31,768  2014-04-10    11:28 PM
# 37   31,835  2014-04-25    11:40 PM
# 38   31,844  2014-04-27     1:40 AM
# 39   31,845  2014-04-26    11:40 PM
#
#                                               address     charge_description  \
# 30            100 E FRANKLIN ST CHAPEL HILL, NC 27514  DRIVING W/LIC REVOKED
# 31      PRITCHARD AVE & CARR ST CHAPEL HILL, NC 27516         OPEN CONTAINER
# 32   PRITCHARD AVE NEAR CARR ST CHAPEL HILL, NC 27516         OPEN CONTAINER
# 33  828 MARTIN LUTHER KING JR BLVD CHAPEL HILL, NC...   LARCENY -  ALL OTHER
# 34        FORSYTH AND LEGION RD CHAPEL HILL, NC 27514            PWISD II CS
# 35        FORSYTH AND LEGION RD CHAPEL HILL, NC 27514        DRUGS-MISD POSS
# 36        400 BLK CHURCH STREET CHAPEL HILL, NC 27516         OPEN CONTAINER
# 37  110 W CAMERON AVE/PITTSBORO ST CHAPEL HILL, NC...    UNDERAGE POSSESSION
# 38       112 1/2 W. FRANKLIN ST CHAPEL HILL, NC 27516    UNDERAGE POSSESSION
# 39        100 BLOCK MALLETTE ST CHAPEL HILL, NC 27516         OPEN CONTAINER
#
#     ucr_code felony_or_misdemeanor  arrestee_s_age arrestee_s_sex  \
# 30       0.0                     M            26.0              M
# 31       0.0                     M            22.0              F
# 32       0.0                     M            21.0              F
# 33       1.0                     M            26.0              M
# 34       2.0                     F            31.0              M
# 35       2.0                     M            31.0              M
# 36       0.0                     M            21.0              M
# 37       0.0                     M            19.0              F
# 38       0.0                     M            21.0              F
# 39       0.0                     M            29.0              M
#
#    arrestee_ethnicity  arrestee_s_race_nan  arrestee_s_race_W  \
# 30                NaN                  0.0                0.0
# 31                NaN                  0.0                1.0
# 32                NaN                  0.0                1.0
# 33                NaN                  0.0                0.0
# 34                NaN                  0.0                0.0
# 35                NaN                  0.0                0.0
# 36                NaN                  0.0                1.0
# 37                NaN                  0.0                1.0
# 38                NaN                  0.0                1.0
# 39                  H                  0.0                1.0
#
#     arrestee_s_race_O  arrestee_s_race_I  arrestee_s_race_H  \
# 30                0.0                0.0                0.0
# 31                0.0                0.0                0.0
# 32                0.0                0.0                0.0
# 33                0.0                0.0                0.0
# 34                0.0                0.0                0.0
# 35                0.0                0.0                0.0
# 36                0.0                0.0                0.0
# 37                0.0                0.0                0.0
# 38                0.0                0.0                0.0
# 39                0.0                0.0                0.0
#
#     arrestee_s_race_B  arrestee_s_race_U  arrestee_s_race_A
# 30                1.0                0.0                0.0
# 31                0.0                0.0                0.0
# 32                0.0                0.0                0.0
# 33                1.0                0.0                0.0
# 34                1.0                0.0                0.0
# 35                1.0                0.0                0.0
# 36                0.0                0.0                0.0
# 37                0.0                0.0                0.0
# 38                0.0                0.0                0.0
# 39                0.0                0.0                0.0

# %% [markdown]
# TESTS TO BE COMPLETED:
#
# - Connor
#        -Logistic Regression
#
#
# - Faith
#        -k-nearest Neighbors
#
#
# - Sandra
#        -Linear and Quadratic Discriminant Analysis
#
#
# - Sam
#        -Support Vector Machine
#
#
# Each individual will run the test and then bootstrap or cross validate, then add that to the CV_Group Presentation. It is up to the individual if they want to run the test once, then bootstrap (like the class examples go). Please save all work though, so we have it to add to the document now, or down the road.

# %% [markdown]
# ##### LINEAR AND QUADRATIC DISCRIMINANT ANALYSIS:

# %%
import matplotlib.colors as pltco
import numpy.random as rn
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
pam_3 = pam_3.dropna(subset=['arrestee_s_age', 'ucr_code'])

# %%
X = np.atleast_2d(np.array(pam_3['arrestee_s_age'])).transpose()
y = np.array(pam_3['ucr_code'])

# %%
n = X.shape[0]
test = int(0.20*n)            
perm = rn.permutation(n)   
X = X[perm]
y = y[perm]
X_test = X[:test]       
y_test = y[:test]
X_train = X[test:]     
y_train = y[test:]

# %%
clf = LinearDiscriminantAnalysis()
clf.fit(X_train, y_train);
print('Training Error: {}'.format(clf.score(X_train, y_train)))
print('Testing Error: {}'.format(clf.score(X_test, y_test)))
# Out:
# Training Error: 0.7548466932490031
# Testing Error: 0.7626512651265126

# %% [markdown]
# Now, checking the performance with bootstraps:

# %%
num = 60 
Xboot = [0]*num
yboot = [0]*num

# %%
n = X.shape[0]
for s in range(num):
    sample = np.random.randint(0, n, n)  
    Xboot[s] = X[sample, :]
    yboot[s] = y[sample]

# %%
test = int(0.20*n)

labels = [ ['train_{}'.format(x), 'test_{}'.format(x)] for x in range(1, maxk+1)]
labels = [x for sublist in labels for x in sublist]

# %%
Error = pa.DataFrame(  np.array([0]*num*2*maxk).reshape(num, 2*maxk), columns = labels)

for s in range(num):
    X_test = Xboot[s][:test]
    y_test = yboot[s][:test]
    X_train = Xboot[s][test:]
    y_train = yboot[s][test:]
    
    for k in range(maxk):
        clf = LinearDiscriminantAnalysis()
        clf.fit(X_train, y_train)
        Error.iloc[s, 2*k] = clf.score(X_train, y_train) 
        Error.iloc[s, 2*k+1] = clf.score(X_test, y_test)
      
Error_mean = [0]*2*maxk
Error_std = [0]*2*maxk
for c in range(2*maxk):
    Error_mean[c] = np.mean(Error.iloc[:num, c])
    Error_std[c] = np.std(Error.iloc[:num, c])
    
Error = Error.append( pa.Series(Error_mean, index=Error.columns), ignore_index=True)
Error = Error.append( pa.Series(Error_std, index=Error.columns), ignore_index=True)
Error.index = list(range(num)) + ['Mean', 'Standard Deviation']
Error.tail()
# Out:
#                      train_1    test_1   train_2    test_2   train_3  \
# 57                  0.757459  0.755776  0.757459  0.755776  0.757459
# 58                  0.755672  0.754125  0.755672  0.754125  0.755672
# 59                  0.753540  0.754950  0.753540  0.754950  0.753540
# Mean                0.756540  0.756083  0.756540  0.756083  0.756540
# Standard Deviation  0.003852  0.007675  0.003852  0.007675  0.003852
#
#                       test_3   train_4    test_4   train_5    test_5  ...  \
# 57                  0.755776  0.757459  0.755776  0.757459  0.755776  ...
# 58                  0.754125  0.755672  0.754125  0.755672  0.754125  ...
# 59                  0.754950  0.753540  0.754950  0.753540  0.754950  ...
# Mean                0.756083  0.756540  0.756083  0.756540  0.756083  ...
# Standard Deviation  0.007675  0.003852  0.007675  0.003852  0.007675  ...
#
#                     train_16   test_16  train_17   test_17  train_18  \
# 57                  0.757459  0.755776  0.757459  0.755776  0.757459
# 58                  0.755672  0.754125  0.755672  0.754125  0.755672
# 59                  0.753540  0.754950  0.753540  0.754950  0.753540
# Mean                0.756540  0.756083  0.756540  0.756083  0.756540
# Standard Deviation  0.003852  0.007675  0.003852  0.007675  0.003852
#
#                      test_18  train_19   test_19  train_20   test_20
# 57                  0.755776  0.757459  0.755776  0.757459  0.755776
# 58                  0.754125  0.755672  0.754125  0.755672  0.754125
# 59                  0.754950  0.753540  0.754950  0.753540  0.754950
# Mean                0.756083  0.756540  0.756083  0.756540  0.756083
# Standard Deviation  0.007675  0.003852  0.007675  0.003852  0.007675
#
# [5 rows x 40 columns]

# %% [markdown]
# Here is the quadratic discriminant analysis and bootstraps to check performance:

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
clf2 = QuadraticDiscriminantAnalysis()
clf2.fit(X_train, y_train)
print('Training Error: {}'.format(clf.score(X_train, y_train)))
print('Testing Error: {}'.format(clf.score(X_test, y_test)))
# Out:
# Training Error: 0.7535404922315413
# Testing Error: 0.754950495049505

# %%
num = 60 
Xboot = [0]*num
yboot = [0]*num

# %%
n = X.shape[0]
for s in range(num):
    sample = np.random.randint(0, n, n)  
    Xboot[s] = X[sample, :]
    yboot[s] = y[sample]

# %%
test = int(0.20*n)

labels = [ ['train_{}'.format(x), 'test_{}'.format(x)] for x in range(1, maxk+1)]
labels = [x for sublist in labels for x in sublist]

# %%
Error = pa.DataFrame(  np.array([0]*num*2*maxk).reshape(num, 2*maxk), columns = labels)

for s in range(num):
    X_test = Xboot[s][:test]
    y_test = yboot[s][:test]
    X_train = Xboot[s][test:]
    y_train = yboot[s][test:]
    
    for k in range(maxk):
        clf = QuadraticDiscriminantAnalysis()
        clf.fit(X_train, y_train)
        Error.iloc[s, 2*k] = clf.score(X_train, y_train) 
        Error.iloc[s, 2*k+1] = clf.score(X_test, y_test)
      
Error_mean = [0]*2*maxk
Error_std = [0]*2*maxk
for c in range(2*maxk):
    Error_mean[c] = np.mean(Error.iloc[:num, c])
    Error_std[c] = np.std(Error.iloc[:num, c])
    
Error = Error.append( pa.Series(Error_mean, index=Error.columns), ignore_index=True)
Error = Error.append( pa.Series(Error_std, index=Error.columns), ignore_index=True)
Error.index = list(range(num)) + ['Mean', 'Standard Deviation']
Error.tail()
# Out:
#                      train_1    test_1   train_2    test_2   train_3  \
# 57                  0.752991  0.773927  0.752991  0.773927  0.752991
# 58                  0.758628  0.757151  0.758628  0.757151  0.758628
# 59                  0.759797  0.748625  0.759797  0.748625  0.759797
# Mean                0.757015  0.757119  0.757015  0.757119  0.757015
# Standard Deviation  0.003272  0.006944  0.003272  0.006944  0.003272
#
#                       test_3   train_4    test_4   train_5    test_5  ...  \
# 57                  0.773927  0.752991  0.773927  0.752991  0.773927  ...
# 58                  0.757151  0.758628  0.757151  0.758628  0.757151  ...
# 59                  0.748625  0.759797  0.748625  0.759797  0.748625  ...
# Mean                0.757119  0.757015  0.757119  0.757015  0.757119  ...
# Standard Deviation  0.006944  0.003272  0.006944  0.003272  0.006944  ...
#
#                     train_16   test_16  train_17   test_17  train_18  \
# 57                  0.752991  0.773927  0.752991  0.773927  0.752991
# 58                  0.758628  0.757151  0.758628  0.757151  0.758628
# 59                  0.759797  0.748625  0.759797  0.748625  0.759797
# Mean                0.757015  0.757119  0.757015  0.757119  0.757015
# Standard Deviation  0.003272  0.006944  0.003272  0.006944  0.003272
#
#                      test_18  train_19   test_19  train_20   test_20
# 57                  0.773927  0.752991  0.773927  0.752991  0.773927
# 58                  0.757151  0.758628  0.757151  0.758628  0.757151
# 59                  0.748625  0.759797  0.748625  0.759797  0.748625
# Mean                0.757119  0.757015  0.757119  0.757015  0.757119
# Standard Deviation  0.006944  0.003272  0.006944  0.003272  0.006944
#
# [5 rows x 40 columns]
